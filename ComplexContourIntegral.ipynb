# %%
ContourIntegrate[E^(I z)/(z^3 + 1/8), z \[Element] RegularPolygon[6]]
# Out:
#                (3 I)/4         Sqrt[3]                 Sqrt[3]
# 4 Pi (2 I - 2 E        (I Cosh[-------] + Sqrt[3] Sinh[-------]))
#                                   4                       4
# -----------------------------------------------------------------
#                                 I/2
#                              3 E
